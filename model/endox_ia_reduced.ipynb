# %% [markdown]
# # Endox IA (modelo reducido)

# %% [markdown]
# ## Accesos a Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
from PIL import Image

base_path = '/content/drive/MyDrive/Proyectos/limas-endodonticas/dataset'
flat_dataset = '/content/drive/MyDrive/Proyectos/limas-endodonticas/dataset_flat_reduced'

# %% [markdown]
# ## Dataset aplanado

# %%
# Sistemas incluidos en este modelo reducido
SISTEMAS = {
  '3d-files',
  'blue-shaper',
  'apical-shaper',
  'mg3-blue',
  'rising',
  'micromega-one-curve-mini',
  'slim-shaper'
}

valid_ext = ('.jpg', '.jpeg', '.png', '.bmp', '.webp')

os.makedirs(flat_dataset, exist_ok=True)

total_images = 0
total_classes = 0
class_distribution = {}

for sistema in os.listdir(base_path):
  if sistema not in SISTEMAS:
    continue

  sistema_path = os.path.join(base_path, sistema)
  if not os.path.isdir(sistema_path):
    continue

  for lima in os.listdir(sistema_path):
    lima_path = os.path.join(sistema_path, lima)
    if not os.path.isdir(lima_path):
      continue

    class_name = f"{sistema}_{lima}"
    dest_path = os.path.join(flat_dataset, class_name)
    os.makedirs(dest_path, exist_ok=True)

    for filename in os.listdir(lima_path):
      if not filename.lower().endswith(valid_ext):
        continue

      src = os.path.join(lima_path, filename)
      dst = os.path.join(dest_path, filename)

      if os.path.exists(dst):
        continue

      img = Image.open(src)
      w, h = img.size
      target_ratio = 3 / 4

      if (w / h) > target_ratio:
        new_w = int(h * target_ratio)
        left = (w - new_w) // 2
        img = img.crop((left, 0, left + new_w, h))
      else:
        new_h = int(w / target_ratio)
        top = (h - new_h) // 2
        img = img.crop((0, top, w, top + new_h))

      img.save(dst)

    num_images = len([f for f in os.listdir(dest_path) if f.lower().endswith(valid_ext)])
    class_distribution[class_name] = num_images
    total_images += num_images
    total_classes += 1

print(f"Dataset preparado:")
print(f"   - Sistemas incluidos: {len(SISTEMAS)}")
print(f"   - Total de clases (limas): {total_classes}")
print(f"   - Total de imágenes: {total_images}")
print(f"   - Promedio imágenes/clase: {total_images/total_classes:.1f}")
print(f"\nDistribución por clase:")
for class_name, count in sorted(class_distribution.items()):
  print(f"   {class_name}: {count} imágenes")
# Out:
# Dataset preparado:
#    - Sistemas incluidos: 7
#    - Total de clases (limas): 24
#    - Total de imágenes: 3601
#    - Promedio imágenes/clase: 150.0
#
# Distribución por clase:
#    3d-files_1-f25: 176 imágenes
#    3d-files_2-f30: 173 imágenes
#    3d-files_3-s30: 178 imágenes
#    apical-shaper_1-z30: 176 imágenes
#    apical-shaper_2-z35: 175 imágenes
#    apical-shaper_3-z40: 166 imágenes
#    apical-shaper_4-z50: 163 imágenes
#    blue-shaper_1-z1: 117 imágenes
#    blue-shaper_2-z2: 115 imágenes
#    blue-shaper_3-z3: 117 imágenes
#    blue-shaper_4-z4: 117 imágenes
#    mg3-blue_1-sv: 146 imágenes
#    mg3-blue_2-px: 146 imágenes
#    mg3-blue_3-g1: 147 imágenes
#    mg3-blue_4-g2x: 144 imágenes
#    mg3-blue_5-g2: 144 imágenes
#    rising_1-17: 127 imágenes
#    rising_2-13: 124 imágenes
#    rising_3-25: 123 imágenes
#    rising_4-30: 124 imágenes
#    rising_5-28: 126 imágenes
#    slim-shaper_1-zs1: 208 imágenes
#    slim-shaper_2-zs2: 196 imágenes
#    slim-shaper_3-zs3: 173 imágenes

# %%
# Incluyendo Micromega One Curve mini pos aplanamiento

# Dataset preparado:
#    - Sistemas incluidos: 1
#    - Total de clases (limas): 4
#    - Total de imágenes: 598
#    - Promedio imágenes/clase: 149.5

# Distribución por clase:
#    micromega-one-curve-mini_1-n45-0.4: 158 imágenes
#    micromega-one-curve-mini_2-n35-0.4: 139 imágenes
#    micromega-one-curve-mini_3-n25-0.6: 160 imágenes
#    micromega-one-curve-mini_4-n25-0.4: 141 imágenes

# %% [markdown]
# ### Datasets para entrenamiento

# %%
import tensorflow as tf
import numpy as np

# %%
IMG_SIZE = (448, 448)
BATCH_SIZE = 16
DATA_DIR = flat_dataset

train_dataset = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  validation_split=0.2,
  subset="training",
  seed=42,
  image_size=IMG_SIZE,
  batch_size=BATCH_SIZE,
  color_mode='rgb'
)

validation_dataset = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  validation_split=0.2,
  subset="validation",
  seed=42,
  image_size=IMG_SIZE,
  batch_size=BATCH_SIZE,
  color_mode='rgb'
)

class_names = train_dataset.class_names
NUM_CLASSES = len(class_names)

print(f"Dataset cargado:")
print(f"   - Clases: {NUM_CLASSES}")
print(f"   - Tamaño imagen: {IMG_SIZE}")
print(f"   - Batch size: {BATCH_SIZE}")
print(f"\nClases:")
for i, name in enumerate(class_names):
  print(f"   {i}: {name}")
# Out:
# Found 4199 files belonging to 28 classes.
# Using 3360 files for training.
# Found 4199 files belonging to 28 classes.
# Using 839 files for validation.
# Dataset cargado:
#    - Clases: 28
#    - Tamaño imagen: (448, 448)
#    - Batch size: 16
#
# Clases:
#    0: 3d-files_1-f25
#    1: 3d-files_2-f30
#    2: 3d-files_3-s30
#    3: apical-shaper_1-z30
#    4: apical-shaper_2-z35
#    5: apical-shaper_3-z40
#    6: apical-shaper_4-z50
#    7: blue-shaper_1-z1
#    8: blue-shaper_2-z2
#    9: blue-shaper_3-z3
#    10: blue-shaper_4-z4
#    11: mg3-blue_1-sv
#    12: mg3-blue_2-px
#    13: mg3-blue_3-g1
#    14: mg3-blue_4-g2x
#    15: mg3-blue_5-g2
#    16: micromega-one-curve-mini_1-n45-0.4
#    17: micromega-one-curve-mini_2-n35-0.4
#    18: micromega-one-curve-mini_3-n25-0.6
#    19: micromega-one-curve-mini_4-n25-0.4
#    20: rising_1-17
#    21: rising_2-13
#    22: rising_3-25
#    23: rising_4-30
#    24: rising_5-28
#    25: slim-shaper_1-zs1
#    26: slim-shaper_2-zs2
#    27: slim-shaper_3-zs3

# %% [markdown]
# ## Data augmentation

# %%
# Función para transformaciones
class RandomRotate90(tf.keras.layers.Layer):
  def call(self, images, training=None):
    if training:
      k = tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32)
      return tf.image.rot90(images, k=k)
    return images

# %%
# Augmentation
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomFlip('vertical'),
  RandomRotate90(),
  tf.keras.layers.RandomZoom(0.3),
  tf.keras.layers.RandomBrightness(0.3),
  tf.keras.layers.RandomContrast(0.3),
])

AUTOTUNE = tf.data.AUTOTUNE
train_dataset_augmented = train_dataset.prefetch(AUTOTUNE)
validation_dataset = validation_dataset.prefetch(AUTOTUNE)

print("Augmentation definido:")
print("   - RandomFlip horizontal y vertical")
print("   - RandomRotate90 (0°, 90°, 180°, 270°)")
print("   - RandomZoom: ±30%")
print("   - RandomBrightness: ±30%")
print("   - RandomContrast: ±30%")
# Out:
# Augmentation definido:
#    - RandomFlip horizontal y vertical
#    - RandomRotate90 (0°, 90°, 180°, 270°)
#    - RandomZoom: ±30%
#    - RandomBrightness: ±30%
#    - RandomContrast: ±30%

# %% [markdown]
# ## Construcción del modelo

# %%
# Construcción del modelo
base_model = tf.keras.applications.EfficientNetB0(
  input_shape=IMG_SIZE + (3,),
  include_top=False,
  weights='imagenet'
)
base_model.trainable = False

inputs = tf.keras.Input(shape=IMG_SIZE + (3,))
x = data_augmentation(inputs)
x = tf.keras.applications.efficientnet.preprocess_input(x)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.Dropout(0.4)(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.3)(x)
outputs = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)

model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
  metrics=[
    'accuracy',
    tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name='top_3_accuracy'),
    tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name='top_5_accuracy')
  ]
)

print(f"Modelo construido (Fase 1: Congelado)")
print(f"   - Base: EfficientNetB0")
print(f"   - Parámetros totales: {model.count_params():,}")
print(f"   - Clases: {NUM_CLASSES}")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Modelo construido (Fase 1: Congelado)
#    - Base: EfficientNetB0
#    - Parámetros totales: 4,850,111
#    - Clases: 28

# %% [markdown]
# ## Entrenamiento del modelo

# %% [markdown]
# ### Fase 1: entrenamiento con el modelo base

# %%
# Entrenamiento Fase 1
callbacks_phase1 = [
  tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    restore_best_weights=True,
    verbose=1
  ),
  tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
  )
]

NUM_EPOCHS = 20

print("Fase 1: Entrenamiento (modelo base congelado)")
print("   - Learning rate: 1e-4")
print(f"   - Epochs: {NUM_EPOCHS} (con early stopping)")
print()

history_phase1 = model.fit(
  train_dataset_augmented,
  validation_data=validation_dataset,
  epochs=NUM_EPOCHS,
  callbacks=callbacks_phase1,
  verbose=1
)
# Out:
# Fase 1: Entrenamiento (modelo base congelado)
#    - Learning rate: 1e-4
#    - Epochs: 20 (con early stopping)
#
# Epoch 1/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 158s 662ms/step - accuracy: 0.1039 - loss: 3.6574 - top_3_accuracy: 0.2423 - top_5_accuracy: 0.3509 - val_accuracy: 0.2133 - val_loss: 2.8662 - val_top_3_accuracy: 0.4148 - val_top_5_accuracy: 0.5375 - learning_rate: 1.0000e-04
# Epoch 2/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 187s 620ms/step - accuracy: 0.2762 - loss: 2.5546 - top_3_accuracy: 0.5122 - top_5_accuracy: 0.6348 - val_accuracy: 0.5733 - val_loss: 1.6693 - val_top_3_accuracy: 0.8272 - val_top_5_accuracy: 0.9046 - learning_rate: 1.0000e-04
# Epoch 3/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 162s 713ms/step - accuracy: 0.3976 - loss: 1.9738 - top_3_accuracy: 0.6702 - top_5_accuracy: 0.7905 - val_accuracy: 0.7569 - val_loss: 0.9526 - val_top_3_accuracy: 0.9416 - val_top_5_accuracy: 0.9762 - learning_rate: 1.0000e-04
# Epoch 4/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 144s 683ms/step - accuracy: 0.4914 - loss: 1.6183 - top_3_accuracy: 0.7679 - top_5_accuracy: 0.8607 - val_accuracy: 0.8093 - val_loss: 0.6831 - val_top_3_accuracy: 0.9678 - val_top_5_accuracy: 0.9893 - learning_rate: 1.0000e-04
# Epoch 5/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 127s 605ms/step - accuracy: 0.5643 - loss: 1.3730 - top_3_accuracy: 0.8220 - top_5_accuracy: 0.9071 - val_accuracy: 0.8462 - val_loss: 0.5327 - val_top_3_accuracy: 0.9762 - val_top_5_accuracy: 0.9964 - learning_rate: 1.0000e-04
# Epoch 6/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 147s 701ms/step - accuracy: 0.6140 - loss: 1.2061 - top_3_accuracy: 0.8640 - top_5_accuracy: 0.9342 - val_accuracy: 0.8653 - val_loss: 0.4368 - val_top_3_accuracy: 0.9833 - val_top_5_accuracy: 0.9976 - learning_rate: 1.0000e-04
# Epoch 7/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 172s 817ms/step - accuracy: 0.6610 - loss: 1.0539 - top_3_accuracy: 0.8905 - top_5_accuracy: 0.9491 - val_accuracy: 0.8772 - val_loss: 0.3752 - val_top_3_accuracy: 0.9928 - val_top_5_accuracy: 0.9976 - learning_rate: 1.0000e-04
# Epoch 8/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 179s 707ms/step - accuracy: 0.6857 - loss: 0.9619 - top_3_accuracy: 0.9131 - top_5_accuracy: 0.9637 - val_accuracy: 0.8987 - val_loss: 0.3269 - val_top_3_accuracy: 0.9952 - val_top_5_accuracy: 0.9988 - learning_rate: 1.0000e-04
# Epoch 9/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 148s 705ms/step - accuracy: 0.7045 - loss: 0.8942 - top_3_accuracy: 0.9199 - top_5_accuracy: 0.9658 - val_accuracy: 0.9070 - val_loss: 0.2844 - val_top_3_accuracy: 0.9964 - val_top_5_accuracy: 0.9988 - learning_rate: 1.0000e-04
# Epoch 10/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 121s 575ms/step - accuracy: 0.7182 - loss: 0.8335 - top_3_accuracy: 0.9283 - top_5_accuracy: 0.9673 - val_accuracy: 0.9118 - val_loss: 0.2548 - val_top_3_accuracy: 0.9964 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 11/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 126s 601ms/step - accuracy: 0.7554 - loss: 0.7432 - top_3_accuracy: 0.9432 - top_5_accuracy: 0.9735 - val_accuracy: 0.9190 - val_loss: 0.2343 - val_top_3_accuracy: 0.9964 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 12/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 148s 631ms/step - accuracy: 0.7685 - loss: 0.6936 - top_3_accuracy: 0.9557 - top_5_accuracy: 0.9836 - val_accuracy: 0.9213 - val_loss: 0.2242 - val_top_3_accuracy: 0.9964 - val_top_5_accuracy: 0.9988 - learning_rate: 1.0000e-04
# Epoch 13/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 152s 679ms/step - accuracy: 0.7801 - loss: 0.6442 - top_3_accuracy: 0.9580 - top_5_accuracy: 0.9881 - val_accuracy: 0.9261 - val_loss: 0.2004 - val_top_3_accuracy: 0.9976 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 14/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 133s 632ms/step - accuracy: 0.7929 - loss: 0.6385 - top_3_accuracy: 0.9548 - top_5_accuracy: 0.9818 - val_accuracy: 0.9344 - val_loss: 0.1851 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 15/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 133s 589ms/step - accuracy: 0.8003 - loss: 0.5802 - top_3_accuracy: 0.9682 - top_5_accuracy: 0.9875 - val_accuracy: 0.9416 - val_loss: 0.1605 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 16/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 144s 600ms/step - accuracy: 0.8101 - loss: 0.5649 - top_3_accuracy: 0.9673 - top_5_accuracy: 0.9866 - val_accuracy: 0.9452 - val_loss: 0.1596 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 17/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 142s 676ms/step - accuracy: 0.8101 - loss: 0.5653 - top_3_accuracy: 0.9658 - top_5_accuracy: 0.9878 - val_accuracy: 0.9440 - val_loss: 0.1538 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 18/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 125s 596ms/step - accuracy: 0.8235 - loss: 0.5099 - top_3_accuracy: 0.9696 - top_5_accuracy: 0.9899 - val_accuracy: 0.9499 - val_loss: 0.1470 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 19/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 163s 777ms/step - accuracy: 0.8220 - loss: 0.5132 - top_3_accuracy: 0.9738 - top_5_accuracy: 0.9929 - val_accuracy: 0.9559 - val_loss: 0.1431 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 20/20
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 182s 682ms/step - accuracy: 0.8369 - loss: 0.4907 - top_3_accuracy: 0.9759 - top_5_accuracy: 0.9917 - val_accuracy: 0.9523 - val_loss: 0.1359 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 19.

# %% [markdown]
# ### Fase 2: ajuste fino

# %%
# Fase 2: Fine-tuning
base_model.trainable = True

for layer in base_model.layers[:-30]:
  layer.trainable = False

model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
  metrics=[
    'accuracy',
    tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name='top_3_accuracy'),
    tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name='top_5_accuracy')
  ]
)

callbacks_phase2 = [
  tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=7,
    restore_best_weights=True,
    verbose=1
  ),
  tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-8,
    verbose=1
  )
]

NUM_EPOCHS = 15

print("Fase 2: Fine-tuning")
print("   - Capas descongeladas: últimas 30 de EfficientNetB0")
print("   - Learning rate: 1e-5")
print(f"   - Epochs: {NUM_EPOCHS} (con early stopping)")
print()

history_phase2 = model.fit(
  train_dataset_augmented,
  validation_data=validation_dataset,
  epochs=NUM_EPOCHS,
  callbacks=callbacks_phase2,
  verbose=1
)
# Out:
# Fase 2: Fine-tuning
#    - Capas descongeladas: últimas 30 de EfficientNetB0
#    - Learning rate: 1e-5
#    - Epochs: 15 (con early stopping)
#
# Epoch 1/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 138s 574ms/step - accuracy: 0.6060 - loss: 1.2872 - top_3_accuracy: 0.8452 - top_5_accuracy: 0.9146 - val_accuracy: 0.9070 - val_loss: 0.2592 - val_top_3_accuracy: 0.9940 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 2/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 141s 673ms/step - accuracy: 0.6539 - loss: 1.0636 - top_3_accuracy: 0.8807 - top_5_accuracy: 0.9443 - val_accuracy: 0.9035 - val_loss: 0.2758 - val_top_3_accuracy: 0.9905 - val_top_5_accuracy: 0.9988 - learning_rate: 1.0000e-05
# Epoch 3/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 157s 747ms/step - accuracy: 0.6958 - loss: 0.9511 - top_3_accuracy: 0.9095 - top_5_accuracy: 0.9577 - val_accuracy: 0.9154 - val_loss: 0.2561 - val_top_3_accuracy: 0.9940 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 4/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 148s 706ms/step - accuracy: 0.7080 - loss: 0.8903 - top_3_accuracy: 0.9202 - top_5_accuracy: 0.9628 - val_accuracy: 0.9178 - val_loss: 0.2379 - val_top_3_accuracy: 0.9952 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 5/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 149s 710ms/step - accuracy: 0.7235 - loss: 0.8237 - top_3_accuracy: 0.9280 - top_5_accuracy: 0.9699 - val_accuracy: 0.9201 - val_loss: 0.2237 - val_top_3_accuracy: 0.9952 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 6/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 135s 641ms/step - accuracy: 0.7476 - loss: 0.7900 - top_3_accuracy: 0.9333 - top_5_accuracy: 0.9711 - val_accuracy: 0.9297 - val_loss: 0.2085 - val_top_3_accuracy: 0.9964 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 7/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 150s 679ms/step - accuracy: 0.7595 - loss: 0.7250 - top_3_accuracy: 0.9467 - top_5_accuracy: 0.9750 - val_accuracy: 0.9333 - val_loss: 0.2012 - val_top_3_accuracy: 0.9964 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 8/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 141s 673ms/step - accuracy: 0.7649 - loss: 0.7102 - top_3_accuracy: 0.9461 - top_5_accuracy: 0.9792 - val_accuracy: 0.9309 - val_loss: 0.1917 - val_top_3_accuracy: 0.9964 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 9/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 125s 594ms/step - accuracy: 0.7643 - loss: 0.6890 - top_3_accuracy: 0.9494 - top_5_accuracy: 0.9833 - val_accuracy: 0.9368 - val_loss: 0.1795 - val_top_3_accuracy: 0.9976 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 10/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 132s 631ms/step - accuracy: 0.7848 - loss: 0.6424 - top_3_accuracy: 0.9574 - top_5_accuracy: 0.9845 - val_accuracy: 0.9428 - val_loss: 0.1703 - val_top_3_accuracy: 0.9976 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 11/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 132s 631ms/step - accuracy: 0.7845 - loss: 0.6274 - top_3_accuracy: 0.9586 - top_5_accuracy: 0.9836 - val_accuracy: 0.9392 - val_loss: 0.1659 - val_top_3_accuracy: 0.9976 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 12/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 149s 710ms/step - accuracy: 0.8012 - loss: 0.5728 - top_3_accuracy: 0.9682 - top_5_accuracy: 0.9899 - val_accuracy: 0.9404 - val_loss: 0.1615 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 13/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 148s 703ms/step - accuracy: 0.8054 - loss: 0.5779 - top_3_accuracy: 0.9637 - top_5_accuracy: 0.9860 - val_accuracy: 0.9404 - val_loss: 0.1594 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 14/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 135s 641ms/step - accuracy: 0.8122 - loss: 0.5516 - top_3_accuracy: 0.9676 - top_5_accuracy: 0.9896 - val_accuracy: 0.9464 - val_loss: 0.1530 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Epoch 15/15
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 136s 613ms/step - accuracy: 0.8036 - loss: 0.5531 - top_3_accuracy: 0.9673 - top_5_accuracy: 0.9887 - val_accuracy: 0.9428 - val_loss: 0.1494 - val_top_3_accuracy: 0.9988 - val_top_5_accuracy: 1.0000 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 14.

# %% [markdown]
# ## Evaluación del modelo

# %%
# Evaluación final
print("Evaluación final del modelo")
print("=" * 50)

val_results = model.evaluate(validation_dataset, verbose=0)

print(f"\nMétricas de validación:")
print(f"   - Loss:           {val_results[0]:.4f}")
print(f"   - Accuracy:       {val_results[1]:.2%}")
print(f"   - Top-3 Accuracy: {val_results[2]:.2%}")
print(f"   - Top-5 Accuracy: {val_results[3]:.2%}")

print(f"\nInterpretación:")
if val_results[1] >= 0.95:
  print(f"   ✓ Rendimiento excelente (>95%)")
elif val_results[1] >= 0.85:
  print(f"   ✓ Rendimiento muy bueno (85-95%)")
elif val_results[1] >= 0.75:
  print(f"   ✓ Rendimiento aceptable (75-85%)")
else:
  print(f"   ✗ Rendimiento bajo (<75%) - revisar datos o modelo")
# Out:
# Evaluación final del modelo
# ==================================================
#
# Métricas de validación:
#    - Loss:           0.1530
#    - Accuracy:       94.64%
#    - Top-3 Accuracy: 99.88%
#    - Top-5 Accuracy: 100.00%
#
# Interpretación:
#    ✓ Rendimiento muy bueno (85-95%)

# %%
for images, labels in validation_dataset.take(1):
  sample_image = images[0]
  sample_label = labels[0].numpy()

# Predecir
img_array = tf.expand_dims(sample_image, 0)
predictions = model.predict(img_array, verbose=0)[0]

top_k = 5
top_k_indices = np.argsort(predictions)[-top_k:][::-1]

print(f"Clase real: {class_names[sample_label]}")
print(f"\nTop {top_k} predicciones:")
for i, idx in enumerate(top_k_indices):
  print(f"   {i+1}. {class_names[idx]}: {predictions[idx]*100:.2f}%")
# Out:
# Clase real: rising_4-30
#
# Top 5 predicciones:
#    1. rising_4-30: 99.60%
#    2. rising_5-28: 0.28%
#    3. rising_2-13: 0.05%
#    4. apical-shaper_1-z30: 0.02%
#    5. 3d-files_3-s30: 0.02%

# %% [markdown]
# ### Precisión individual por clase

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
# Obtener predicciones y etiquetas reales
y_true = []
y_pred = []

for images, labels in validation_dataset:
  predictions = model.predict(images, verbose=0)
  y_pred.extend(np.argmax(predictions, axis=1))
  y_true.extend(labels.numpy())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Precisión por clase
report = classification_report(
  y_true,
  y_pred,
  target_names=class_names,
  output_dict=True
)

# Ordenar clases por precisión descendente
class_precisions = {
  name: report[name]['precision']
  for name in class_names
}
class_precisions_sorted = sorted(
  class_precisions.items(),
  key=lambda x: x[1],
  reverse=True
)

print("Precisión por clase (ordenada):")
print(f"{'Clase':<40} {'Precisión':>10}")
print("-" * 52)
for class_name, precision in class_precisions_sorted:
  bar = "█" * int(precision * 20)
  print(f"{class_name:<40} {precision*100:>8.2f}%  {bar}")

print(f"\nMedia:  {report['macro avg']['precision']*100:.2f}%")
print(f"Accuracy total: {report['accuracy']*100:.2f}%")
# Out:
# Precisión por clase (ordenada):
# Clase                                     Precisión
# ----------------------------------------------------
# 3d-files_1-f25                             100.00%  ████████████████████
# 3d-files_2-f30                             100.00%  ████████████████████
# 3d-files_3-s30                             100.00%  ████████████████████
# apical-shaper_2-z35                        100.00%  ████████████████████
# apical-shaper_3-z40                        100.00%  ████████████████████
# apical-shaper_4-z50                        100.00%  ████████████████████
# blue-shaper_1-z1                           100.00%  ████████████████████
# blue-shaper_2-z2                           100.00%  ████████████████████
# blue-shaper_3-z3                           100.00%  ████████████████████
# blue-shaper_4-z4                           100.00%  ████████████████████
# mg3-blue_3-g1                              100.00%  ████████████████████
# micromega-one-curve-mini_3-n25-0.6         100.00%  ████████████████████
# micromega-one-curve-mini_4-n25-0.4         100.00%  ████████████████████
# rising_4-30                                100.00%  ████████████████████
# rising_5-28                                100.00%  ████████████████████
# slim-shaper_1-zs1                          100.00%  ████████████████████
# slim-shaper_2-zs2                          100.00%  ████████████████████
# apical-shaper_1-z30                         97.50%  ███████████████████
# rising_1-17                                 95.83%  ███████████████████
# rising_3-25                                 95.00%  ███████████████████
# slim-shaper_3-zs3                           95.00%  ███████████████████
# micromega-one-curve-mini_2-n35-0.4          91.30%  ██████████████████
# micromega-one-curve-mini_1-n45-0.4          91.18%  ██████████████████
# mg3-blue_2-px                               88.89%  █████████████████
# mg3-blue_1-sv                               79.07%  ███████████████
# mg3-blue_5-g2                               76.92%  ███████████████
# rising_2-13                                 75.00%  ███████████████
# mg3-blue_4-g2x                              60.00%  ████████████
#
# Media:  94.49%
# Accuracy total: 94.64%

# %% [markdown]
# ## Visualización

# %% [markdown]
# ### Gráfico del historial del entrenamiento

# %%
def plot_history(history1, history2, metric, title):
  epochs1 = range(1, len(history1.history[metric]) + 1)
  epochs2 = range(
    len(epochs1) + 1,
    len(epochs1) + len(history2.history[metric]) + 1
  )

  plt.plot(epochs1, history1.history[metric], 'b-', label='Fase 1 Train', alpha=0.7)
  plt.plot(epochs1, history1.history[f'val_{metric}'], 'b--', label='Fase 1 Val', alpha=0.7)
  plt.plot(epochs2, history2.history[metric], 'r-', label='Fase 2 Train', alpha=0.7)
  plt.plot(epochs2, history2.history[f'val_{metric}'], 'r--', label='Fase 2 Val', alpha=0.7)
  plt.axvline(x=len(epochs1), color='gray', linestyle=':', alpha=0.5, label='Inicio Fase 2')
  plt.xlabel('Epoch')
  plt.ylabel(metric.capitalize())
  plt.title(title)
  plt.legend(loc='best')
  plt.grid(alpha=0.3)

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plot_history(history_phase1, history_phase2, 'accuracy', 'Accuracy: Fase 1 + Fase 2')

plt.subplot(1, 2, 2)
plot_history(history_phase1, history_phase2, 'loss', 'Loss: Fase 1 + Fase 2')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matriz de confusión

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(18, 16))
disp = ConfusionMatrixDisplay(
  confusion_matrix=cm,
  display_labels=class_names
)
disp.plot(
  cmap=plt.cm.Blues,
  xticks_rotation='vertical',
  ax=plt.gca(),
  colorbar=False
)
plt.title('Matriz de Confusión')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exportar el modelo

# %% [markdown]
# ### Reconstrucción del modelo de inferencia

# %%
# Reconstruir modelo de inferencia sin augmentation
inputs = tf.keras.Input(shape=IMG_SIZE + (3,))
x = tf.keras.applications.efficientnet.preprocess_input(inputs)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.Dropout(0.4)(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.3)(x)
outputs = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)

inference_model = tf.keras.Model(inputs, outputs)

# Transferir pesos
for inf_layer, train_layer in zip(inference_model.layers[1:], model.layers[2:]):
  inf_layer.set_weights(train_layer.get_weights())

# Verificar accuracy
inference_model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
  metrics=['accuracy']
)
results = inference_model.evaluate(validation_dataset, verbose=0)
print(f"Accuracy inference_model: {results[1]:.2%}  ← debe ser ~94.64%")
# Out:
# Accuracy inference_model: 94.64%  ← debe ser ~94.64%

# %% [markdown]
# ### Exportar

# %%
# !pip install tensorflowjs -q
# Out:
# 2026-08-04 05:36:17.538080: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1785821777.559172   54404 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1785821777.566066   54404 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1785821777.584672   54404 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1785821777.584705   54404 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1785821777.584709   54404 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1785821777.584718   54404 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorflowjs_converter", line 8, in <module>
#     sys.exit(pip_main())
#              ^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflowjs/converters/converter.py", line 959, in pip_main
#     main([' '.join(sys.argv[1:])])
#   File "/usr/local/lib/python3.12/dist-packages/tensorflowjs/converters/converter.py", line 963, in main
#     convert(argv[0].split(' '))
#   File "/usr/local/lib/python3.12/dist-packages/tensorflowjs/converters/converter.py", line 949, in convert
#     _dispatch_converter(input_format, output_format, args, quantization_dtype_map,
#   File "/usr/local/lib/python3.12/dist-packages/tensorflowjs/converters/converter.py", line 655, in _dispatch_converter
#     tf_saved_model_conversion_v2.convert_tf_saved_model(
#   File "/usr/local/lib/python3.12/dist-packages/tensorflowjs/converters/tf_saved_model_conversion_v2.py", line 982, in convert_tf_saved_model
#     _convert_tf_saved_model(output_dir, saved_model_dir=saved_model_dir,
#   File "/usr/local/lib/python3.12/dist-packages/tensorflowjs/converters/tf_saved_model_conversion_v2.py", line 757, in _convert_tf_saved_model
#     saved_model_sigature = _find_signature(saved_model_dir, saved_model_tags,
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflowjs/converters/tf_saved_model_conversion_v2.py", line 589, in _find_signature
#     meta_graph = get_meta_graph_def(saved_model_dir, saved_model_tags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/tools/saved_model_utils.py", line 113, in get_meta_graph_def
#     saved_model = read_saved_model(saved_model_dir)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/tools/saved_model_utils.py", line 51, in read_saved_model
#     raise IOError("SavedModel file does not exist at: %s" % saved_model_dir)
# OSError: SavedModel file does not exist at: {saved_model_path}

# %%
import os
import shutil

model_output_path = '/content/drive/MyDrive/Proyectos/limas-endodonticas/modelo/outputs/endox-ia-reduced-v1'
os.makedirs(model_output_path, exist_ok=True)

saved_model_local = '/content/saved_model'
tfjs_local = '/content/tfjs'

for path in [saved_model_local, tfjs_local]:
  if os.path.exists(path):
    shutil.rmtree(path)

# Keras en Drive
keras_path = os.path.join(model_output_path, 'endox-ia-reduced.keras')
inference_model.save(keras_path)
print(f"✓ Keras guardado: {keras_path}")

# SavedModel en disco local
tf.saved_model.save(inference_model, saved_model_local)
print(f"✓ SavedModel local: {os.listdir(saved_model_local)}")

# Convertir a tfjs en disco local
os.environ['SAVED_MODEL_LOCAL'] = saved_model_local
os.environ['TFJS_LOCAL'] = tfjs_local
# !tensorflowjs_converter \
    --input_format=tf_saved_model \
    --output_format=tfjs_graph_model \
    $SAVED_MODEL_LOCAL \
    $TFJS_LOCAL
print(f"✓ tfjs local: {os.listdir(tfjs_local)}")

# Copiar a Drive
saved_model_drive = os.path.join(model_output_path, 'saved_model')
tfjs_drive = os.path.join(model_output_path, 'tfjs')
shutil.copytree(saved_model_local, saved_model_drive, dirs_exist_ok=True)
shutil.copytree(tfjs_local, tfjs_drive, dirs_exist_ok=True)

print(f"✓ SavedModel en Drive: {os.listdir(saved_model_drive)}")
print(f"✓ tfjs en Drive: {os.listdir(tfjs_drive)}")
# Out:
# ✓ Keras guardado: /content/drive/MyDrive/Proyectos/limas-endodonticas/modelo/outputs/endox-ia-reduced-v1/endox-ia-reduced.keras
# ✓ SavedModel local: ['saved_model.pb', 'assets', 'fingerprint.pb', 'variables']
# 2026-08-04 05:56:10.043840: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1785822970.078984   59647 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1785822970.090309   59647 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1785822970.116435   59647 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1785822970.116473   59647 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1785822970.116481   59647 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1785822970.116488   59647 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
# 2026-08-04 05:56:16.167903: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1785822976.169784   59647 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9507 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1785822978.689478   59647 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785822978.689733   59647 single_machine.cc:374] Starting new session
# I0000 00:00:1785822978.697459   59647 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9507 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# ✓ tfjs local: ['group1-shard5of5.bin', 'group1-shard4of5.bin', 'group1-shard3of5.bin', 'model.json', 'group1-shard1of5.bin', 'group1-shard2of5.bin']
# ✓ SavedModel en Drive: ['saved_model.pb', 'assets', 'fingerprint.pb', 'variables']
# ✓ tfjs en Drive: ['group1-shard5of5.bin', 'group1-shard4of5.bin', 'group1-shard3of5.bin', 'model.json', 'group1-shard1of5.bin', 'group1-shard2of5.bin']

# %% [markdown]
# ## Clases del modelo

# %%
for i, name in enumerate(class_names):
  print(f"{i}: {name}")
# Out:
# 0: 3d-files_1-f25
# 1: 3d-files_2-f30
# 2: 3d-files_3-s30
# 3: apical-shaper_1-z30
# 4: apical-shaper_2-z35
# 5: apical-shaper_3-z40
# 6: apical-shaper_4-z50
# 7: blue-shaper_1-z1
# 8: blue-shaper_2-z2
# 9: blue-shaper_3-z3
# 10: blue-shaper_4-z4
# 11: mg3-blue_1-sv
# 12: mg3-blue_2-px
# 13: mg3-blue_3-g1
# 14: mg3-blue_4-g2x
# 15: mg3-blue_5-g2
# 16: micromega-one-curve-mini_1-n45-0.4
# 17: micromega-one-curve-mini_2-n35-0.4
# 18: micromega-one-curve-mini_3-n25-0.6
# 19: micromega-one-curve-mini_4-n25-0.4
# 20: rising_1-17
# 21: rising_2-13
# 22: rising_3-25
# 23: rising_4-30
# 24: rising_5-28
# 25: slim-shaper_1-zs1
# 26: slim-shaper_2-zs2
# 27: slim-shaper_3-zs3
